# %%
import pandas as pd

fileName = "data/07291600.csv"
df = pd.read_csv(fileName)

# %%
# Display shape
print("Shape:", df.shape)

print(df.head())

df.info()
# Out:
# Shape: (10, 28)
#                                                 name  \
# 0                        E.SUN COMMERCIAL BANK, LTD.
# 1                CATHAY UNITED BANK COMPANY, LIMITED
# 2  CHINA CONSTRUCTION BANK (ASIA) CORPORATION LIM...
# 3                     FUBON BANK (HONG KONG) LIMITED
# 4      J.P. MORGAN SECURITIES (ASIA PACIFIC) LIMITED
#
#                                        local_address  \
# 0  SUITES 2701, 2710-14, 27/F AND 28/F, TOWER 6, ...
# 1  10/F, LEE GARDEN THREE, 1 SUNNING ROAD, CAUSEW...
# 2  28/F, CCB TOWER, NO. 3 CONNAUGHT ROAD CENTRAL,...
# 3  FUBON BANK BUILDING, 38 DES VOEUX ROAD CENTRAL...
# 4  18/F & 23-29/F, CHATER HOUSE, 8 CONNAUGHT ROAD...
#
#                                    principle_address                     type  \
# 0  NO. 117, SEC.3, MINSHENG E. ROAD, SONGSHAN DIS...            Licensed Bank
# 1  1/F, NO. 7, SONGREN ROAD, TAIPEI CITY 110, TAI...            Licensed Bank
# ...

# %%
df.describe(include='all')
# Out:
#                                name  \
# count                            10
# unique                           10
# top     E.SUN COMMERCIAL BANK, LTD.
# freq                              1
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN
#
#                                             local_address  \
# count                                                  10
# unique                                                 10
# top     SUITES 2701, 2710-14, 27/F AND 28/F, TOWER 6, ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# ...

# %%
sb = MlSandbox("housing.csv", 
               numerical=["ZN","INDUS","NOX","RM","AGE","DIS","RAD","TAX","PTRATIO","B","LSTAT","UNK"], 
               numerical_log=[], 
               one_hot=["CHAS"], 
               boolean=[], 
               objective="CRIM", 
               objective_type="regression")

# %%
sb.linearRegression(random_state=60)
# Out:
# Mean Squared Error: 23.80
